# %%
import numpy
import pandas
from scipy import stats, integrate
import matplotlib.pyplot as plt

import seaborn as sns

sns.set(color_codes=True)
numpy.random.seed(sum(map(ord, "distributions")))
sns.set(rc={"figure.figsize": (6, 6)})
% matplotlib inline

# %%
# 加载sns内部的数据集
iris = sns.load_dataset("iris")
# pairplot作图，对角线上是变量自己的直方图，其他的是和别的变量的散点图
sns.pairplot(iris)

# %%
# 加载内部数据集
tips = sns.load_dataset("tips")
tips.head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>total_bill</th>
#       <th>tip</th>
#       <th>sex</th>
#       <th>smoker</th>
#       <th>day</th>
#       <th>time</th>
#       <th>size</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>16.99</td>
#       <td>1.01</td>
#       <td>Female</td>
#       <td>No</td>
#       <td>Sun</td>
#       <td>Dinner</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>10.34</td>
#       <td>1.66</td>
#       <td>Male</td>
#       <td>No</td>
#       <td>Sun</td>
#       <td>Dinner</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>21.01</td>
# ...

# %%
# regplot和lmplot都可以绘制回归关系，推荐用regplot
sns.set()
# 使用regplot绘制回归分析
sns.regplot(x="total_bill", y="tip", data=tips)

# %%
# 使用lmplot绘制回归分析
sns.lmplot(x="total_bill", y="tip", data=tips)

# %%
# 绘制size和tip的回归，但是size是确定的几个值，所以有点不适合
sns.regplot(x="size", y="tip", data=tips)

# %%
# 对size的值，添加一些小的抖动，让数值更适合绘制回归，x_jitter设置抖动的值
# 可以看到和上面的图做对比的话，size的值是有抖动的
sns.regplot(x="size", y="tip", data=tips, x_jitter=.05)
