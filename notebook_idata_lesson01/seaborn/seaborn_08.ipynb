# %%
% matplotlib inline
import numpy
import pandas
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid", color_codes=True)

numpy.random.seed(sum(map(ord, "categorical")))
titanic = sns.load_dataset("titanic")
titanic[:3]
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>survived</th>
#       <th>pclass</th>
#       <th>sex</th>
#       <th>age</th>
#       <th>sibsp</th>
#       <th>parch</th>
#       <th>fare</th>
#       <th>embarked</th>
#       <th>class</th>
#       <th>who</th>
#       <th>adult_male</th>
#       <th>deck</th>
#       <th>embark_town</th>
#       <th>alive</th>
#       <th>alone</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>3</td>
#       <td>male</td>
#       <td>22.0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>7.2500</td>
#       <td>S</td>
#       <td>Third</td>
#       <td>man</td>
#       <td>True</td>
#       <td>NaN</td>
#       <td>Southampton</td>
#       <td>no</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>1</td>
#       <td>female</td>
#       <td>38.0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>71.2833</td>
#       <td>C</td>
#       <td>First</td>
#       <td>woman</td>
#       <td>False</td>
#       <td>C</td>
#       <td>Cherbourg</td>
#       <td>yes</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>3</td>
#       <td>female</td>
#       <td>26.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>7.9250</td>
#       <td>S</td>
#       <td>Third</td>
#       <td>woman</td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>Southampton</td>
#       <td>yes</td>
#       <td>True</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
tips = sns.load_dataset("tips")
tips[:3]
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>survived</th>
#       <th>pclass</th>
#       <th>sex</th>
#       <th>age</th>
#       <th>sibsp</th>
#       <th>parch</th>
#       <th>fare</th>
#       <th>embarked</th>
#       <th>class</th>
#       <th>who</th>
#       <th>adult_male</th>
#       <th>deck</th>
#       <th>embark_town</th>
#       <th>alive</th>
#       <th>alone</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>3</td>
#       <td>male</td>
#       <td>22.0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>7.2500</td>
#       <td>S</td>
#       <td>Third</td>
#       <td>man</td>
#       <td>True</td>
#       <td>NaN</td>
#       <td>Southampton</td>
#       <td>no</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>1</td>
#       <td>female</td>
#       <td>38.0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>71.2833</td>
#       <td>C</td>
#       <td>First</td>
#       <td>woman</td>
#       <td>False</td>
#       <td>C</td>
#       <td>Cherbourg</td>
#       <td>yes</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>3</td>
#       <td>female</td>
#       <td>26.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>7.9250</td>
#       <td>S</td>
#       <td>Third</td>
#       <td>woman</td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>Southampton</td>
#       <td>yes</td>
#       <td>True</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
iris = sns.load_dataset("iris")
iris[:3]
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>survived</th>
#       <th>pclass</th>
#       <th>sex</th>
#       <th>age</th>
#       <th>sibsp</th>
#       <th>parch</th>
#       <th>fare</th>
#       <th>embarked</th>
#       <th>class</th>
#       <th>who</th>
#       <th>adult_male</th>
#       <th>deck</th>
#       <th>embark_town</th>
#       <th>alive</th>
#       <th>alone</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>3</td>
#       <td>male</td>
#       <td>22.0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>7.2500</td>
#       <td>S</td>
#       <td>Third</td>
#       <td>man</td>
#       <td>True</td>
#       <td>NaN</td>
#       <td>Southampton</td>
#       <td>no</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>1</td>
#       <td>female</td>
#       <td>38.0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>71.2833</td>
#       <td>C</td>
#       <td>First</td>
#       <td>woman</td>
#       <td>False</td>
#       <td>C</td>
#       <td>Cherbourg</td>
#       <td>yes</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>3</td>
#       <td>female</td>
#       <td>26.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>7.9250</td>
#       <td>S</td>
#       <td>Third</td>
#       <td>woman</td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>Southampton</td>
#       <td>yes</td>
#       <td>True</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# 查看每一天的total_bill的情况
sns.stripplot(x="day", y="total_bill", data=tips)

# %%
# 这里使用jitter使得数据的显示有抖动，这个抖动仅仅是显示的时候有用。
# 抖动之后，这个图和上图比对的话，看起来就比较方便
sns.stripplot(x="day", y="total_bill", data=tips, jitter=True)

# %%
# 另一种显示的方式
sns.swarmplot(x="day", y="total_bill", data=tips)

# %%
# 在上图的基础上，再设置hue属性，也就是数据再按照sex字段再来分一次
sns.swarmplot(x="day", y="total_bill", hue="sex", data=tips)

# %%
# 也可以横着显示
sns.swarmplot(x="total_bill", y="day", hue="time", data=tips)

# %%
# 盒图，可以方便的看出离群点
sns.boxplot(x="day", y="total_bill", hue="time", data=tips)

# %%
# 另一种形式的盒图
sns.violinplot(x="total_bill", y="day", hue="time", data=tips)

# %%
# 分开显示，split
sns.violinplot(x="day", y="total_bill", hue="sex", data=tips, split=True)
