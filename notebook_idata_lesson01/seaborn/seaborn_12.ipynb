# %%
% matplotlib inline
import matplotlib.pyplot as plt
import numpy
import seaborn as sns

numpy.random.seed(0)
sns.set_style("whitegrid")

# %%
uniform_data = numpy.random.rand(3, 3)
print(uniform_data)
# 绘制热度图
sns.heatmap(uniform_data)
# Out:
# [[ 0.5488135   0.71518937  0.60276338]
#  [ 0.54488318  0.4236548   0.64589411]
#  [ 0.43758721  0.891773    0.96366276]]

# %%
# 设置最小值和最大值，vmin和vmax
sns.heatmap(uniform_data, vmin=0.2, vmax=0.5)

# %%
normal_data = numpy.random.randn(3, 3)
print(normal_data)
# 中间值是0
sns.heatmap(normal_data, center=0)
# Out:
# [[ 0.27519832 -0.96075461  0.37692697]
#  [ 0.03343893  0.68056724 -1.56349669]
#  [-0.56669762 -0.24214951  1.51439128]]

# %%
# 加载数据
flights = sns.load_dataset("flights")
flights[:3]
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>year</th>
#       <th>month</th>
#       <th>passengers</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1949</td>
#       <td>January</td>
#       <td>112</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1949</td>
#       <td>February</td>
#       <td>118</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1949</td>
#       <td>March</td>
#       <td>132</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# year为x轴，month为y轴，passengers为对应的值
flights = flights.pivot("month", "year", "passengers")
sns.heatmap(flights)

# %%
# 在热度图中显示出值，fmt为值的数据格式，annot为True的时候显示
sns.heatmap(flights, annot=True, fmt="d")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-9eb6e0368742> in <module>()
#       1 # 在热度图中显示出值，fmt为值的数据格式，annot为True的时候显示
# ----> 2 sns.heatmap(flights)
#
# D:\Coding\Anaconda3\lib\site-packages\seaborn\matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     515     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     516                           annot_kws, cbar, cbar_kws, xticklabels,
# --> 517                           yticklabels, mask)
#     518
#     519     # Add the pcolormesh kwargs here
#
# D:\Coding\Anaconda3\lib\site-packages\seaborn\matrix.py in __init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
# ...

# %%
# linewidths设置分割线的宽度
sns.heatmap(flights, linewidths=.5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-591e306b096f> in <module>()
#       1 # linewidths设置分割线的宽度
# ----> 2 sns.heatmap(flights, linewidths=.5)
#
# D:\Coding\Anaconda3\lib\site-packages\seaborn\matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     515     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     516                           annot_kws, cbar, cbar_kws, xticklabels,
# --> 517                           yticklabels, mask)
#     518
#     519     # Add the pcolormesh kwargs here
#
# D:\Coding\Anaconda3\lib\site-packages\seaborn\matrix.py in __init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
# ...

# %%
# 使用其他的颜色
sns.heatmap(flights, cmap="YlGnBu")

# %%
# 是否显示颜色条，cbar为False的时候不显示
sns.heatmap(flights, cbar=False)
